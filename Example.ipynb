# %%
#Basic

print("Hello Mehwish")
# Out:
# Hello Mehwish

# %%
#Addition

a=2
b=3
add=a+b
print(add)
# Out:
# 5

# %%
#Grade using user values

marks=input("Enter your marks: ")
if marks>='90':
    print("Grade is A")
elif marks>='80':
    print("Grade is B")
elif marks>='70':
    print("Grade is C")
else:
    print("Grade is D")
# Out:
# Enter your marks:  78
# Grade is C

# %%
#Grade

marks=95
if marks>=90:
    print("Grade is A")
elif marks>=80:
    print("Grade is B")
elif marks>=70:
    print("Grade is C")
else:
    print("Grade is D")
# Out:
# Grade is A

# %%
#Sick

youAreSick=input("Are you sick?")
if youAreSick=='Yes':
    print("Go to the doctor")
else:
    print("Lets go on a trip")
# Out:
# Are you sick? Yes
# Go to the doctor

# %%
#User login

isUserLoggedIn=False
if not isUserLoggedIn:
    print("Redirect to login")
print("Make purchase")
# Out:
# Redirect to login
# Make purchase
